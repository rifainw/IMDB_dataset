# %%
# Mengimport library yang dibutuhkan
import numpy as np
import pandas as pd

# %%
# Mengimport dataset IMDB 
imdb_data = pd.read_csv("https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv",encoding="latin1")

# %%
# Mengetahui total baris dari dataset (sebelum dilakukan drop duplicates)
imdb_data.shape[0]
# Out:
# 3781

# %%
# Mengetahui total kolom dari dataset
imdb_data.shape[1]
# Out:
# 36

# %%
print('Rows in IMDB_data had been drop duplicates is {} and columns is {}'.format(imdb_data.shape[0],imdb_data.shape[1]))
# Out:
# Rows in IMDB_data had been drop duplicates is 3781 and columns is 36

# %%
# Menghilangkan data observasi yang terduplikasi berdasarkan fitur 'movie_title'
imdb = imdb_data.drop_duplicates(subset="movie_title")
imdb.shape
# Out:
# (3679, 36)

# %%
# Mengetahui informasi umum dari dataset
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3679 entries, 0 to 3780
# Data columns (total 36 columns):
# movie_ID                     3679 non-null int64
# movie_title                  3679 non-null object
# duration                     3679 non-null int64
# color                        3679 non-null int64
# title_year                   3679 non-null int64
# country                      3679 non-null object
# language                     3679 non-null object
# content_rating               3679 non-null object
# budget_USD                   3679 non-null int64
# gross_USD                    3679 non-null int64
# net_USD                      3679 non-null int64
# profitable                   3679 non-null int64
# director_name                3679 non-null object
# director_top20?              3679 non-null object
# director_facebook?           3679 non-null int64
# director_facebook_likes      3679 non-null int64
# actor_1_name                 3679 non-null object
# ...

# %%
# Mengetahui informasi 5 baris awal dari dataset
imdb
# Out:
#       movie_ID                               movie_title  duration  color  \
# 0            1                                    Avatar       178      1
# 1            2  Pirates of the Caribbean: At World's End       169      1
# 2            3                     The Dark Knight Rises       164      1
# 3            4                              Spider-Man 3       156      1
# 4            5        Batman v Superman: Dawn of Justice       183      1
# ...        ...                                       ...       ...    ...
# 3776      3777                            New Year's Eve       113      1
# 3777      3778                             Boogie Nights       155      1
# 3778      3779                        Battle of the Year       110      1
# 3779      3780                                The Master       144      1
# 3780      3781                        500 Days of Summer        95      1
#
#       title_year country language content_rating  budget_USD  gross_USD  ...  \
# ...

# %%
# Mengetahui nama-nama kolom yang ada pada dataset
imdb.columns
# Out:
# Index(['movie_ID', 'movie_title', 'duration', 'color', 'title_year', 'country',
#        'language', 'content_rating', 'budget_USD', 'gross_USD', 'net_USD',
#        'profitable', 'director_name', 'director_top20?', 'director_facebook?',
#        'director_facebook_likes', 'actor_1_name', 'actor_top20?',
#        'actor_1_facebook?', 'actor_1_facebook_likes', 'actor_2_name',
#        'actor_top20?.1', 'actor_2_facebook?', 'actor_2_facebook_likes',
#        'actor_3_name', 'actor_top20?.2', 'actor_3_facebook?',
#        'actor_3_facebook_likes', 'cast_total_facebook_likes',
#        'movie_facebook?', 'movie_facebook_likes;', 'facenumber_in_poster',
#        'num_voted_users', 'num_user_for_reviews', 'imdb_score',
#        'imdb_top_250'],
#       dtype='object')

# %%
# Mengetahui 10 nama sutradara teratas yang paling sering menyutradarai sebuah film pada fitur "director_name" 
imdb["director_name"].value_counts().head(10)
# Out:
# Steven Spielberg     25
# Woody Allen          19
# Clint Eastwood       19
# Martin Scorsese      16
# Ridley Scott         16
# Spike Lee            15
# Renny Harlin         15
# Steven Soderbergh    14
# Tim Burton           14
# Ron Howard           13
# Name: director_name, dtype: int64

# %%
# Mengetahui 10 nama aktor teratas yang paling sering memainkan peran utama pada fitur "actor_1_name" 
imdb["actor_1_name"].value_counts().head(10)
# Out:
# Robert De Niro       42
# Johnny Depp          34
# Nicolas Cage         30
# Denzel Washington    29
# J.K. Simmons         28
# Bruce Willis         27
# Matt Damon           27
# Robert Downey Jr.    25
# Harrison Ford        25
# Liam Neeson          24
# Name: actor_1_name, dtype: int64

# %%
# Mengetahui total banyaknya film yang dirilis berdasarkan tahun rilisnya
imdb["title_year"].value_counts().head(20)
# Out:
# 2002    186
# 2006    185
# 2005    178
# 2009    175
# 2004    175
# 2008    175
# 2001    173
# 2011    169
# 2010    167
# 2013    157
# 1999    156
# 2012    156
# 2000    154
# 2007    150
# 2003    144
# 2014    143
# 2015    120
# 1998    117
# 1997    102
# 1996     93
# Name: title_year, dtype: int64

# %%
# Mengetahui berapa macam kategori bahasa yang digunakan pada fitur "language"
imdb["language"].value_counts()
# Out:
# English       3527
# French          33
# Spanish         23
# Mandarin        13
# Japanese        10
# German          10
# Cantonese        7
# Hindi            5
# Portuguese       5
# Italian          5
# Korean           4
# Norwegian        4
# Danish           3
# Thai             3
# Dutch            3
# Persian          3
# Aboriginal       2
# Indonesian       2
# Dari             2
# Hebrew           2
# Aramaic          1
# Hungarian        1
# Bosnian          1
# Arabic           1
# Kazakh           1
# None             1
# Vietnamese       1
# Russian          1
# Maya             1
# Filipino         1
# Zulu             1
# Mongolian        1
# Czech            1
# Name: language, dtype: int64

# %%
# Mengetahui 10 nama film berbahasa Inggris dengan nilai budget teratas
imdb[imdb['language']=='English'][['movie_title','budget_USD','title_year']].sort_values(by=['budget_USD'],ascending=False)[0:10].reset_index(drop=True)
# Out:
#                                  movie_title  budget_USD  title_year
# 0    The Messenger: The Story of Joan of Arc   390000000        1999
# 1   Pirates of the Caribbean: At World's End   300000000        2007
# 2                                John Carter   263700000        2012
# 3                                    Tangled   260000000        2010
# 4                               Spider-Man 3   258000000        2007
# 5                      The Dark Knight Rises   250000000        2012
# 6         Batman v Superman: Dawn of Justice   250000000        2016
# 7  The Hobbit: The Battle of the Five Armies   250000000        2014
# 8     Harry Potter and the Half-Blood Prince   250000000        2009
# 9                    Avengers: Age of Ultron   250000000        2015

# %%
# Mengetahui durasi film yang paling panjang
imdb['duration'].max()
# Out:
# 325

# %%
# Mengetahui judul film apa yang mempunyai durasi paling panjang, tahun film tersebut, beserta sutradaranya
imdb[imdb['duration']==325][['movie_title','title_year','director_name']].sort_values(by=['title_year'])
# Out:
#        movie_title  title_year   director_name
# 461  Heaven's Gate        1980  Michael Cimino

# %%
# Mengetahui nama-nama film yang disutradarai oleh Steven Spielberg
imdb[imdb["director_name"]=="Steven Spielberg"][["movie_title","title_year"]].sort_values(by=["title_year"])
# Out:
#                                             movie_title  title_year
# 1055                                               Jaws        1975
# 811                  Close Encounters of the Third Kind        1977
# 2116                            Raiders of the Lost Ark        1981
# 1112                         E.T. the Extra-Terrestrial        1982
# 2785               Indiana Jones and the Temple of Doom        1984
# 960                                    The Color Purple        1985
# 3565                 Indiana Jones and the Last Crusade        1989
# 1709                                               Hook        1991
# 312                                       Jurassic Park        1993
# 718                                    Schindler's List        1993
# 2717                                            Amistad        1997
# 238                       The Lost World: Jurassic Park        1997
# 2628                                Saving Private Ryan        1998
# ...

# %%
# Top 10 movies with highest nett profit in 2016
imdb[imdb["title_year"]==2016][["movie_title","net_USD","director_name"]].sort_values(by=["net_USD"],ascending=False)[0:10].reset_index(drop=True)
# Out:
#                           movie_title    net_USD            director_name
# 0                            Deadpool  305024263               Tim Miller
# 1             The Secret Life of Pets  248505540            Yarrow Cheney
# 2                     The Jungle Book  187645141              Jon Favreau
# 3          Captain America: Civil War  157197282            Anthony Russo
# 4  Batman v Superman: Dawn of Justice   80249062              Zack Snyder
# 5                Central Intelligence   76088877  Rawson Marshall Thurber
# 6            The Purge: Election Year   68845130           James DeMonaco
# 7                     The Conjuring 2   62310175                James Wan
# 8                 10 Cloverfield Lane   56897215         Dan Trachtenberg
# 9                          Lights Out   51636016        David F. Sandberg

# %%
# Top 10 movies with highest gross profit in 2016
imdb[imdb["title_year"]==2016][["movie_title","gross_USD","actor_1_name"]].sort_values(by=["gross_USD"],ascending=False)[0:10].reset_index(drop=True)
# Out:
#                           movie_title  gross_USD        actor_1_name
# 0          Captain America: Civil War  407197282   Robert Downey Jr.
# 1                            Deadpool  363024263       Ryan Reynolds
# 2                     The Jungle Book  362645141  Scarlett Johansson
# 3  Batman v Superman: Dawn of Justice  330249062        Henry Cavill
# 4             The Secret Life of Pets  323505540        Steve Coogan
# 5                       Suicide Squad  161087183          Will Smith
# 6                   X-Men: Apocalypse  154985087   Jennifer Lawrence
# 7                     Kung Fu Panda 3  143523463        J.K. Simmons
# 8                    Star Trek Beyond  130468626      Sofia Boutella
# 9                Central Intelligence  126088877      Dwayne Johnson

# %%
# Total of non-English language movies
print("The movie with non-English language :{}".format(imdb[imdb["language"]!="English"].shape[0]))
# Out:
# The movie with non-English language :152

# %%
# Indonesian movies
imdb[imdb["country"]=="Indonesia"]
# Out:
#       movie_ID           movie_title  duration  color  title_year    country  \
# 1476      1477  The Raid: Redemption       102      1        2011  Indonesia
#
#         language content_rating  budget_USD  gross_USD  ...  \
# 1476  Indonesian              R     1100000    4105123  ...
#
#       actor_3_facebook?  actor_3_facebook_likes cast_total_facebook_likes  \
# 1476                  1                      60                      1445
#
#      movie_facebook?  movie_facebook_likes;  facenumber_in_poster  \
# 1476               1                  51000                     0
#
#      num_voted_users  num_user_for_reviews  imdb_score  imdb_top_250
# 1476          148221                   316         7.6             0
#
# [1 rows x 36 columns]

# %%
# Top 3 languages aside English based on total movies
imdb[imdb["language"]!="English"].groupby("language").count().sort_values(by=["movie_ID"],ascending=False)[["movie_ID"]][0:3]
# Out:
#           movie_ID
# language
# French          33
# Spanish         23
# Mandarin        13

# %%
# Top 3 countries with the highest nett profit in all times
imdb.groupby("country").sum().sort_values(by=["net_USD"],ascending=False)[["net_USD"]][0:3]
# Out:
#              net_USD
# country
# USA      50330300012
# UK        1279724445
# Canada     232040577

# %%
# The average budgets of all movies in 2015
x = imdb[imdb["title_year"]==2015][["budget_USD"]].mean()[0]
x
# Out:
# 52102458.333333336

# %%
# The average budgets of all movies in 2016
y = imdb[imdb["title_year"]==2016][["budget_USD"]].mean()[0]
y
# Out:
# 66014754.09836066

# %%
# Which one is higher, average budgets of all movies in 2015 or 2016?
if x > y:
    print('Higher average budget: ${} and year is 2015'.format(x))
elif x < y:
    print('Higher average budget: ${} and year is 2016'.format(y))
else:
    print('No higher average budget')
# Out:
# Higher average budget: $66014754.09836066 and year is 2016

# %%
# What movie that resulted highest nett profit of all times? How much did the movie make?
imdb.sort_values(by=["net_USD"],ascending=False)[["movie_title","title_year","net_USD"]][0:1]
# Out:
#   movie_title  title_year    net_USD
# 0      Avatar        2009  523505847

# %% [markdown]
# Create a new variable called "score_group" ('High' if 'imdb_score' > 7.5 and 'Low' if imdb_score <= 7.5)

# %%
imdb.loc[imdb.imdb_score > 7.5, "score_group"] = "High"
imdb.loc[imdb.imdb_score <= 7.5,"score_group"] = "Low"

# %%
imdb["score_group"]
# Out:
# 0       High
# 1        Low
# 2       High
# 3        Low
# 4        Low
#         ...
# 3776     Low
# 3777    High
# 3778     Low
# 3779     Low
# 3780    High
# Name: score_group, Length: 3679, dtype: object

# %% [markdown]
# Analyze at least 10 variables from which you can start figure out criteria of high rated movie

# %%
imdb['score_group'] = imdb['score_group'].astype('category')
imdb['score_group'].cat.categories = [0,1]
imdb['score_group'] = imdb['score_group'].astype('float')
np.abs(imdb.corr(method= 'kendall')['score_group']).sort_values(ascending=False)[1:11]
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# imdb_top_250             0.516917
# imdb_score               0.499927
# num_voted_users          0.316254
# ...
